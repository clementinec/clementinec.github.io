# %%
import pandas as pd

# %%
ex=pd.read_excel('events/cf25dat.xlsx')

# %%
gx=pd.read_excel('events/20250623 - Detailed Schedule - v10.xlsx')

# %%
g=gx.dropna(subset=['EasyChair'])

# %%
absin=pd.read_csv('CAADFutures_abstractin.csv')

# %%
putabs=dict(zip(absin['#'],absin['Abstract']))

# %%
g['Date']=g['FILTER OPTIONS.1']
# Out:
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_74298/1342371881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g['Date']=g['FILTER OPTIONS.1']

# %%
topicmape=dict(zip(g['EasyChair'],g['session title']))
sessimape=dict(zip(g['EasyChair'],g['session code']))

# %%
timemape=dict(zip(g['EasyChair'],g['Time']))

# %%
idex=ex['ID'].unique()

# %%
g['EasyChair']=g['EasyChair'].astype(str).replace('[','').str.replace(']','').str.strip().str.replace('[','')
# Out:
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_74298/75282077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g['EasyChair']=g['EasyChair'].astype(str).replace('[','').str.replace(']','').str.strip().str.replace('[','')

# %%
g['EasyChair']=g['EasyChair'].astype(int)
# Out:
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_74298/705830128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g['EasyChair']=g['EasyChair'].astype(int)

# %%
datemape=dict(zip(g['EasyChair'],g['Date']))
timemape=dict(zip(g['EasyChair'],g['Time']))

# %%
[c for c in g['EasyChair'].unique() if c not in idex]
# Out:
# []

# %%
[c for c in idex if c not in g['EasyChair'].unique()]
# Out:
# []

# %%
ex=ex.loc[~ex['ID'].isin([214, 376, 283, 27])]

# %%
en=ex[['ID','Title','Authors','Final Topic','Session','Abstract']]
en.reset_index(inplace=True)

# %%
# absin.loc[absin['#']==457]

# %%
# en.head(2)

# %%
# topicmape[238]

# %%
ct=81
for i in [457, 82, 330, 389, 427, 445, 458]:
    try:
        id,aut,title,subs,typesub,timesub,abs=absin.loc[absin['#']==i].values[0]
        en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
    except:
        print(i)
        tnt=g[g['EasyChair']==i]
        en.loc[87]=87+4,tnt['EasyChair'].values[0],tnt['title'].values[0],tnt['authors'].values[0],tnt['session title'].values[0],tnt['session code'].values[0],None
    ct +=1
# Out:
# 458
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[ct]=ct+4,id,title,aut,topicmape[i],sessimape[i],abs
# /var/folders/rs/m2cwbt951nlfsrncdqwyny5h0000gn/T/ipykernel_69328/3367273670.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en.loc[87]=87+4,tnt['EasyChair'].values[0],tnt['title'].values[0],tnt['authors'].values[0],tnt['session title'].values[0],tnt['session code'].values[0],None

# %%
en.loc[en['Final Topic'].isna(),'Final Topic']='Catalytic Interface'
# en.loc[en.tail(6).index,'Final Topic']='Catalyi

# %%
absin
# Out:
#        #                                            Authors  \
# 0      5  Yanting Shen, Mengqing Yu, Chenyu Huang and Ji...
# 1     19  Tinghao Feng, Yulu Zhang, Xinhui Xu, Zhengchen...
# 2     27  Shenzhou Dai, Sihang Liu, Haojun Wang, Yulin C...
# 3     29  Hang Xu, Chengxuan Li, Timur Dogan and Patrick...
# 4     30  Fang-Che Cheng, Henriette Bier, Ningzhu Wang a...
# ..   ...                                                ...
# 159  452  Zhining Wang, Ningyuan Wang, Yue Chen and Zhe Guo
# 160  453                   Chee Meng Chan and Frederick Kim
# 161  454            Taiyang Wang, Peng Luo and Rudi Stouffs
# 162  456  Li Zhang, Jiawei Wang, Zhicheng Wang, Yuetong ...
# 163  457  Matthias Hornung, Markus Renner, Diellza Elsha...
#
#                                                  Title File Submission  \
# 0    Superiority of High-Dimensional Latent Variabl...               ✔
# 1    Integrating Regulatory Compliance In AI-Assist...               ✔
# 2    A Full-Process Digital Method for Recursive Ge...               ✔
# 3    Understand Urban Building Energy Consumption w...               ✔
# 4    Review of Advances in the Robotization of Timb...               ✔
# ..                                                 ...             ...
# 159  Research on Modular Generation and Constructio...               ✔
# 160                              Perceptual Urban Form               ✔
# 161  The optimization of visual perception factors ...               ✔
# 162  Evaluation Method of AI-Generated Architectura...               ✔
# 163  Augmenting IFC-Based BIM Models for Graph Neur...               ✔
#
#     submission type           Time  \
# 0     Regular Paper  Sep 10, 17:16
# 1     Regular Paper  Sep 13, 15:09
# 2     Regular Paper  Sep 15, 17:12
# 3     Regular Paper  Sep 16, 02:20
# 4     Regular Paper  Sep 16, 07:55
# ..              ...            ...
# 159   Regular Paper  Oct 08, 10:38
# 160   Regular Paper  Oct 09, 03:26
# 161   Regular Paper  Oct 09, 09:53
# 162   Regular Paper  Oct 10, 05:50
# 163   Regular Paper  May 15, 09:01
#
#                                               Abstract
# 0    Quantitative descriptions of urban morphology ...
# 1    In the new era of human-computer interaction (...
# 2    The commercial wood processing industry, drive...
# 3    Urban decarbonization is a critical goal in ad...
# 4    Robotic timber construction has advanced signi...
# ..                                                 ...
# 159  The construction logic of traditional dougong ...
# 160  Enabled by growing repositories of urban data,...
# 161  In the realm of public health studies, the spo...
# 162  Abstract. In recent years, Generative Artifici...
# 163  Building Information Modeling (BIM) and Indust...
#
# [164 rows x 7 columns]

# %%
# en.loc[87,'Abstract']=putabs[458]

# %%
# putabs[458]

# %%
# tnt=g[g['EasyChair']==458]
# en.loc[87]=87+4,tnt['EasyChair'],tnt['title'],tnt['a

# %%
tn=absin.loc[absin['#']==i].values

# %%
tn[0][0]
# Out:
# 457

# %%
g[g['EasyChair']==i].values
# Out:
# array([['Catalytic Interfaces', '7/4/2025', '16:50 - 17:10', 'CI',
#         'Catalytic Interfaces Presentation', nan,
#         'CATALYTIC DESIGN INTERFACES: AI-GUIDED BUILDING MASSING AND AUTOMATED COMPLIANCE\n',
#         'Tejas Chavan, Houssame E. Hsain, Camiel Weijenberg and Sayjel V. Patel',
#         458, nan, nan, '16:50 - 17:10', '[ 458 ]',
#         'CATALYTIC DESIGN INTERFACES: AI-GUIDED BUILDING MASSING AND AUTOMATED COMPLIANCE\nBy Tejas Chavan, Houssame E. Hsain, Camiel Weijenberg and Sayjel V. Patel',
#         nan, nan, '7/4/2025']], dtype=object)

# %%
tnt['EasyChair'].values[0]
# Out:
# 458

# %%
ex['ID']
# Out:
# 0     403
# 1     114
# 2     238
# 3     231
# 4     444
#      ...
# 83    330
# 84    389
# 85    427
# 86    445
# 87    458
# Name: ID, Length: 88, dtype: int64

# %%
ex['Date']=ex['ID'].map(datemape)

# %%
ex['Time']=ex['ID'].map(timemape)

# %%
ex['Session']=ex['ID'].map(sessimape)

# %%
ex.to_excel('events/cf25dat.xlsx')
